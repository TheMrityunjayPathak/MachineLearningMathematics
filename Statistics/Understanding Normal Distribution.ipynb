# %% [markdown]
# <div style="background-color:seagreen; padding:8px; border-radius:8px;"><h1 align="center" style="color:white;">Normal Distribution</h1></div>

# %% [markdown]
# ## What is a Normal Distribution?
#
# **Normal distribution, also known as the Gaussian distribution, is a probability distribution that is symmetric about the mean, showing that data near the mean are more frequent in occurrence than data far from the mean.**
#
# ![Normal-distribution-of-SAT-scores.png](attachment:9b576cb5-7778-43b5-b925-c87d6a12aa65.png)
#
# ## Key Points
#
# - **In graphical form, the normal distribution appears as a "bell curve".**
# - **In a normal distribution the mean is zero and the standard deviation is 1. It has zero skew and a kurtosis of 3.**
# - **Normal distributions are symmetrical, but not all symmetrical distributions are normal.**
# - **Many naturally-occurring phenomena tend to approximate the normal distribution.**
# - **In finance, most pricing distributions are not, however, perfectly normal.**

# %% [markdown]
# ## Understanding Normal Distribution
#
# - **The normal distribution is the most common type of distribution assumed in technical stock market analysis and in other types of statistical analyses.**
# - **The standard normal distribution has two parameters: the mean and the standard deviation.**
# - **The normal distribution model is important in statistics and is key to the Central Limit Theorem (CLT).**
# - **The normal distribution is one type of symmetrical distribution.**
# - **Not all symmetrical distributions are normal since some data could appear as two humps or a series of hills in addition to the bell curve that indicates a normal distribution.**

# %% [markdown]
# ## Properties of the Normal Distribution
#
# **The normal distribution has several key features and properties that define it :**
#
# - **First, its mean (average), median (midpoint), and mode (most frequent observation) are all equal to one another. Moreover, these values all represent the peak, or highest point, of the distribution. The distribution then falls symmetrically around the mean, the width of which is defined by the standard deviation.**
#
# ![Properties-of-normal-distributions.png](attachment:dd940d55-440b-4451-8fe8-d3d7c5d3fd3a.png)

# %% [markdown]
# - **The mean is the location parameter while the standard deviation is the scale parameter.**
#     - **The mean determines where the peak of the curve is centered. Increasing the mean moves the curve right, while decreasing it moves the curve left.**
#     - **The standard deviation stretches or squeezes the curve. A small standard deviation results in a narrow curve, while a large standard deviation leads to a wide curve.**
#
# | ![Normal-distributions-with-different-means.png](attachment:a0a57403-a179-4efc-87d3-94731e12d621.png) | ![normal-distributions-with-different-sds.png](attachment:a7db7dcf-fa26-4ffc-b411-6ce6c8bb87b3.png) |
# | :---: | :---: |

# %% [markdown]
# - **Empirical Rule**
#
#     - **The empirical rule, or the 68-95-99.7 rule, tells you where most of your values lie in a normal distribution :**
#     - **Around 68% of values are within 1 standard deviation from the mean.**
#     - **Around 95% of values are within 2 standard deviations from the mean.**
#     - **Around 99.7% of values are within 3 standard deviations from the mean.**
#
# ![Standard-normal-distribution.png](attachment:7cbe4419-cd62-4633-819b-153b24d17228.png)

# %% [markdown]
# - **Skewness and Kurtosis**
#
# **Skewness and kurtosis are statistical measures used to describe the shape and distribution of a dataset. They provide insights into the asymmetry and peakedness of the data, respectively.**
#
# - **Skewness**
#
# **Skewness measures the degree of asymmetry in a distribution. It indicates whether the data is concentrated more on one side of the mean compared to the other. Skewness can be right, left, or zero.**
#
# - **Right skewness : A right skewed distribution has a long tail on the right side, indicating that the majority of the data points are concentrated on the left side of the distribution. The mean is typically greater than the median in a right skewed distribution.**
# - **Left skewness : A left skewed distribution has a long tail on the left side, suggesting that the majority of the data points are concentrated on the right side of the distribution. The mean is usually less than the median in a left skewed distribution.**
# - **Zero skewness : A distribution with zero skewness is perfectly symmetrical, with equal concentrations of data on both sides of the mean. The mean and median are equal in a symmetric distribution.**
#
# **Note**
#
# - **In a distribution with zero skew, the mean and median are equal. (Mean = Median)**
# - **The mean of a right-skewed distribution is almost always greater than its median. (Mean > Median)**
# - **The mean of a left-skewed distribution is almost always less than its median. (Mean < Median)**
#
# ![Skewness-of-a-distribution.png](attachment:e5786ab0-e5a1-4e32-afe0-85828073143d.png)
#
# -  **Kurtosis**
#
# **Kurtosis measures the peakedness or flatness of a distribution, compared to the normal distribution. It describes the distribution of the data in the tails and can be used to identify outliers.**
#
# - **Leptokurtic : A leptokurtic distribution has higher kurtosis than the normal distribution. It means the data has heavier tails and a sharper peak compared to the normal distribution. It indicates a higher probability of extreme values.**
# - **Mesokurtic : A mesokurtic distribution has the same kurtosis as the normal distribution. It implies the distribution has moderate tails and a moderate peak.**
# - **Platykurtic : A platykurtic distribution has lower kurtosis than the normal distribution. It means the data has lighter tails and a flatter peak compared to the normal distribution. It indicates a lower probability of extreme values.**
#
# **Note**
#
# - **Leptokurtic distributions are more kurtotic than a normal distribution. They have kurtosis of more than 3 and excess kurtosis of more than 0. Leptokurtosis is sometimes called positive kurtosis, since the excess kurtosis is positive.**
# - **Mesokurtic distributions have same kurtosis to a normal distributions. Normal distributions have a kurtosis of 3, so any distribution with a kurtosis of approximately 3 is mesokurtic. Normal distributions have an excess kurtosis of 0, so any distribution with an excess kurtosis of approximately 0 is mesokurtic.**
# - **Platykurtic distributions have less kurtosis than a normal distribution. They have kurtosis of less than 3 and excess kurtosis of less than 0. Platykurtosis is sometimes called negative kurtosis, since the excess kurtosis is negative.**
# - `Excess Kurtosis = Kurtosis - 3`
#
# ![The-difference-between-skewness-and-kurtosis.png](attachment:6cc66298-d777-434d-b8ea-45886a4913f5.png)

# %% [markdown]
# ## Formula of Normal Curve
#
# **Once you have the mean and standard deviation of a normal distribution, you can fit a normal curve to your data using a probability density function.**
#
# - **In a probability density function, the area under the curve tells you probability. The normal distribution is a probability distribution, so the total area under the curve is always 1 or 100%.**
# - **The formula for the normal probability density function looks fairly complicated. But to use it, you only need to know the population mean and standard deviation.**
#
# **For any value of x, you can plug in the mean and standard deviation into the formula to find the probability density of the variable taking on that value of x.**
#
# ![quicklatex.com-16763e3b6e3f2bd556458282d64f2627_l3.png](attachment:afbbaa80-c50a-4b1c-94ea-1b088eebdf99.png)
#
# - **Here, f(x) = probability**
# - **x = value of the variable**
# - **μ = mean**
# - **σ = standard deviation**
# - **σ<sup>2</sup> = variance**

# %% [markdown]
# ## What is Standard Normal Distribution?
#
# - **The standard normal distribution, also called the z-distribution, is a special normal distribution where the mean is 0 and the standard deviation is 1.**
# - **Every normal distribution is a version of the standard normal distribution that’s been stretched or squeezed and moved horizontally right or left.**
#
# ![standard-normal-distribution-example (1).png](attachment:8596334d-6db8-4415-98cc-eaed7105d794.png)

# %% [markdown]
# ## Z-Score Formula
#
# - **Z-scores tell you how many standard deviations away from the mean each value lies. You only need to know the mean and standard deviation of your distribution to find the z-score of a value.**
#
# ![quicklatex.com-8c0d11455fb878c25f952eb08d64dc4c_l3.png](attachment:082d1e5d-3790-4db3-829a-d9295b4a3bb7.png)
#
# - **Here, x = individual value**
# - **μ = mean**
# - **σ = standard deviation**
#
# **We convert normal distributions into the standard normal distribution for several reasons :**
#
# - **To find the probability of observations in a distribution falling above or below a given value.**
# - **To find the probability that a sample mean significantly differs from a known population mean.**
# - **To compare scores on different distributions with different means and standard deviations.**
